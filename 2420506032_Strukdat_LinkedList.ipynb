# %% [markdown]
# <a href="https://colab.research.google.com/github/clizardyy/Praktikum-Struktur-Data/blob/main/2420506032_Strukdat_LinkedList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Latihan 1**

# %%
# Latihan 1
print("\nLatihan 1")

# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
        self.task_name = task_name # Nama task
        self.next = None        # Pointer ke node selanjutnya

# Definisi Linked List untuk daftar tugas
class TaskList:
    def __init__(self):
        self.head = None # Node pertama dalam linked list

    # Menambahkan task baru ke linked list
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task # Menjadikan task baru sebagai node pertama
        else:
            current = self.head
            while current.next:
                current = current.next # Menemukan node terakhir
            current.next = new_task # Menambahkan task baru ke akhir linked list

    # Menampilkan daftar task
    def show_tasks(self):
        if not self.head:
            print("Tidak ada task yang tersedia.")
            return

        print("Daftar Task:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.task_name}")
            current = current.next
            count += 1
# Main #

# Membuat objek TaskList
task_list = TaskList()

# Menambahkan task ke linked list
num_tasks = int(input("Masukkan jumlah task yang ingin ditambahkan: "))

# Meminta nama task dari pengguna
for i in range(num_tasks):
    task_name = input(f"Masukkan nama task ke-{i+1}: ")
    task_list.add_task(task_name)

# Menampilkan daftar task
task_list.show_tasks()

# %% [markdown]
# **Latihan 2**

# %%
# Latihan 2
print("\nLatihan 2")

# Definisi Node dalam Doubly Linked List
class PageNode:
    def __init__(self, url):
        self.url = url # Nama halaman
        self.next = None        # Pointer ke node selanjutnya
        self.prev = None        # Pointer ke node sebelumnya

# Definisi Doubly Linked List untuk riwayat browsing
class BrowserHistory:
    def __init__(self):
        self.current = None # Node saat ini dalam linked list

    # Menambahkan halaman baru ke linked list
    def visit_page(self, url):
        new_page = PageNode(url)
        if not self.current:
            self.current = None # Menjadikan halaman baru sebagai node pertama
        else:
            new_page.prev = self.current
            self.current.next = new_page
            self.current = new_page # Pindah ke halaman baru

    # Menampilkan riwayat browsing
    def show_history(self):
        if not self.current:
            print("Riwayat browsing kosong.")
            return

        print("Riwayat Browsing:")
        temp = self.current
        while temp.prev: # Pindah ke halaman pertama
            temp = temp.prev

        count = 1
        while temp:
            print(f"{count}. {temp.url}")
            temp = temp.next
            count += 1

    # Navigasi mundur ke halaman berikutnya
    def go_back(self):
        if self.current and self.current.prev:
            self.current = self.current.prev
            print(f"Kembali ke halaman: {self.current.url}")
        else:
            print("Tidak ada halaman sebelumnya.")

    # Navigasi maju ke halaman sebelumnya
    def go_forward(self):
        if self.current and self.current.next:
            self.current = self.current.next
            print(f"Maju ke halaman: {self.current.url}")
        else:
            print("Tidak ada halaman berikutnya.")
# Main #

# Membuat objek riwayat peramban
history = BrowserHistory()

# Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int(input("Masukkan jumlah halaman yang dikunjungi: "))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, num_pages + 1):
    url = input(f"Masukkan URL halaman ke-{i}: ")
    history.visit_page (url)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
    command = input("\nTekan 'b' untuk kembali, Tekan 'f' untuk maju, Tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()

    if command == 'b':
        history.go_back ()
    elif command == 'f':
        history.go_forward()
    elif command == 'x':
        print("\nKeluar dari riwayat browser.")
        break
    else:
        print("\nPerintah tidak dikenal.")

# %% [markdown]
# **Latihan 3**

# %%
# Latihan 3
print("\nLatihan 3")

# Definisi Node dalam Singly Linked List
class Node:
    def __init__(self, data):
        self.data = data # Menyimpan nilai node
        self.next = None # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
    def __init__(self):
        self.head = None # Awalnya, daftar kosong

    # Menambahkan elemen di awal
    def add_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    # Menambahkan elemen di akhir
    def add_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        temp = self.head
        while temp.next:
            temp = temp.next
        temp.next = new_node

    # Menambahkan elemen di posisi tertentu
    def add_at_position(self, position, data): # Indented to be part of LinkedList class
        if position < 0:
            print(" Posisi tidak valid!")
            return
        new_node = Node(data)
        if position == 0:
            self.add_at_beginning(data)
            return
        temp = self.head
        for _ in range(position - 1):
            if not temp:
                print(" Posisi melebihi panjang daftar!")
                return
            temp = temp.next
        new_node.next = temp.next
        temp.next = new_node

    #Menghapus elemen di awal
    def delete_at_beginning(self): # Indented to be part of LinkedList class
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        self.head = self.head.next

    # Menghapus elemen di akhir
    def delete_at_end(self): # Indented to be part of LinkedList class
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if not self.head.next:
            self.head = None
            return
        temp = self.head
        while temp.next.next:
            temp = temp.next
        temp.next = None

    # Menghapus elemen di posisi tertentu
    def delete_at_position(self, position): # Indented to be part of LinkedList class
        if not self.head:
            print(" Daftar kosong, tidak ada yang bisa dihapus!")
            return
        if position == 0:
            self.head = self.head.next
            return
        temp = self.head
        for _ in range (position - 1):
            if not temp or not temp.next:
                print("Posisi tidak ditemukan!")
                return
            temp = temp.next
            temp.next = temp.next.next

    # Mencari elemen dalam Linked List
    def search(self, key) :  # Indented to be part of LinkedList class
        temp = self.head
        while temp:
            if temp.data == key:
                print(f" Elemen {key} ditemukan dalam daftar!")
                return
            temp = temp.next
        print (f" Elemen {key} tidak ditemukan dalam daftar.")

    # Membalik (reverse) Linked List
    def reverse (self):  # Indented to be part of LinkedList class
        prev = None
        current = self.head
        while current:
            next_node = current.next
            current.next = prev
            prev = current
            current = next_node
        self.head = prev

    # Menampilkan Linked List
    def display (self):  # Indented to be part of LinkedList class
        if not self.head:
            print(" Daftar kosong!")
            return
        temp = self.head
        while temp:
            print (temp.data, end=" -> ")
            temp = temp.next
        print("None")

# Program Utama (Main)

# Membuat objek Linked List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("\nMasukkan jumlah awal elemen dalam daftar: "))
for i in range (num_elements):
    data = int(input(f"Masukkan data ke-{i+1}: "))
    ll.add_at_end(data)

# Menu Operasi Linked List
while True:
    print("\n Pilih Operasi:")
    print("1. Tambah elemen di awal")
    print("2. Tambah elemen di akhir")
    print("3. Tambah elemen di posisi")
    print("4. Hapus elemen di awal")
    print("5. Hapus elemen di akhir")
    print("6. Hapus elemen di posisi tertentu")
    print("7. Cari elemen dalam daftar")
    print("8. Balikkan daftar")
    print("9. Tampilkan daftar")
    print("0. Keluar")

    choice = int(input("\nMasukkan pilihan: "))

    if choice == 1:
        data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
        ll.add_at_beginning(data)
    elif choice == 2:
        data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
        ll.add_at_end(data)
    elif choice == 3:
        position = int(input("Masukkan posisi untuk menambahkan data: "))
        data = int(input("Masukkan data yang ingin ditambahkan: "))
        ll.add_at_position(position, data)
    elif choice == 4:
        ll.delete_at_beginning ()
    elif choice == 5:
        ll.delete_at_end()
    elif choice == 6:
        position = int(input("Masukkan posisi elemen yang ingin dihapus: "))
        ll.delete_at_position(position)
    elif choice == 7:
        key = int (input("Masukkan elemen yang ingin dicari: "))
        ll.search(key)
    elif choice == 8:
        ll.reverse()
        print("Daftar berhasil dibalik!")
    elif choice == 9:
        ll.display()
    elif choice == 0:
        print("\nKeluar dari program.")
        break
    else:
        print("\nPilihan tidak valid, silakan coba lagi!")

# %% [markdown]
# **Tugas**

# %%
# Definisi Node dalam Circular Linked List
class SatpamNode:
    def __init__(self, nama):
        self.nama = nama  # Nama satpam
        self.next = None  # Pointer ke node berikutnya

# Definisi Circular Linked List untuk jadwal piket
class JadwalPiket:
    def __init__(self):
        self.head = None  # Node pertama dalam linked list
        self.size = 0  # Ukuran linked list

    # Menambahkan satpam ke dalam linked list
    def tambah_satpam(self, nama):
        satpam_baru = SatpamNode(nama)
        if not self.head:
            self.head = satpam_baru
            satpam_baru.next = self.head  # Menghubungkan ke dirinya sendiri
        else:
            current = self.head
            while current.next != self.head:
                current = current.next  # Menemukan node terakhir
            current.next = satpam_baru
            satpam_baru.next = self.head  # Menghubungkan node baru ke head
        self.size += 1

    # Menghapus satpam dari linked list
    def hapus_satpam(self, nama):
        if not self.head:
            print("Tidak ada satpam yang terdaftar.")
            return

        current = self.head
        prev = None
        while True:
            if current.nama == nama:
                if prev:
                    prev.next = current.next
                else:
                    # Menghapus head
                    if current.next == self.head:  # Hanya ada satu node
                        self.head = None
                    else:
                        # Mencari node terakhir
                        last = self.head
                        while last.next != self.head:
                            last = last.next
                        last.next = current.next
                        self.head = current.next
                self.size -= 1
                print(f"Satpam {nama} telah dihapus.")
                return
            prev = current
            current = current.next
            if current == self.head:
                break
        print(f"Satpam {nama} tidak ditemukan.")

    # Mencetak jadwal piket selama N hari
    def cetak_jadwal(self, hari=14):
        if not self.head:
            print("Tidak ada satpam yang terdaftar.")
            return

        current = self.head
        print(f"Jadwal Piket Satpam selama {hari} hari:")
        for i in range(hari):
            print(f"Hari {i + 1}: {current.nama}")
            current = current.next  # Berpindah ke satpam berikutnya

    # Mencetak daftar satpam
    def cetak_daftar_satpam(self):
        if not self.head:
            print("Tidak ada satpam yang terdaftar.")
            return

        current = self.head
        print("Daftar Satpam:")
        while True:
            print(current.nama)
            current = current.next
            if current == self.head:
                break

# Program Utama
if __name__ == "__main__":
    # Membuat objek jadwal piket
    jadwal = JadwalPiket()

    # Meminta pengguna memasukkan nama satpam
    for i in range(4):
        nama = input(f"Masukkan nama satpam ke-{i + 1}: ")
        jadwal.tambah_satpam(nama)

    # Mencetak jadwal piket
    jadwal.cetak_jadwal()

    # Mencetak daftar satpam
    jadwal.cetak_daftar_satpam()

    # Menghapus satpam
    nama_hapus = input("Masukkan nama satpam yang ingin dihapus: ")
    jadwal.hapus_satpam(nama_hapus)

    # Mencetak jadwal piket setelah penghapusan
    jadwal.cetak_jadwal()
# Out:
# Masukkan nama satpam ke-1: Aldi
# Masukkan nama satpam ke-2: Ronald
# Masukkan nama satpam ke-3: Lutfi
# Masukkan nama satpam ke-4: Ilyasa
# Jadwal Piket Satpam selama 14 hari:
# Hari 1: Aldi
# Hari 2: Ronald
# Hari 3: Lutfi
# Hari 4: Ilyasa
# Hari 5: Aldi
# Hari 6: Ronald
# Hari 7: Lutfi
# Hari 8: Ilyasa
# Hari 9: Aldi
# Hari 10: Ronald
# Hari 11: Lutfi
# Hari 12: Ilyasa
# Hari 13: Aldi
# Hari 14: Ronald
# Daftar Satpam:
# Aldi
# Ronald
# Lutfi
# Ilyasa
# Masukkan nama satpam yang ingin dihapus: Ronald
# Satpam Ronald telah dihapus.
# Jadwal Piket Satpam selama 14 hari:
# Hari 1: Aldi
# Hari 2: Lutfi
# Hari 3: Ilyasa
# Hari 4: Aldi
# Hari 5: Lutfi
# Hari 6: Ilyasa
# Hari 7: Aldi
# Hari 8: Lutfi
# Hari 9: Ilyasa
# Hari 10: Aldi
# Hari 11: Lutfi
# Hari 12: Ilyasa
# Hari 13: Aldi
# Hari 14: Lutfi
